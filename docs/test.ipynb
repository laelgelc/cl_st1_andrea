# %% [markdown]
# <center>
# <img src="https://laelgelcpublic.s3.sa-east-1.amazonaws.com/lael_50_years_narrow_white.png.no_years.400px_96dpi.png" width="300" alt="LAEL 50 years logo">
# <h3>APPLIED LINGUISTICS GRADUATE PROGRAMME (LAEL)</h3>
# </center>
# <hr>

# %%
import pandas as pd

df_tv_commercials = pd.read_excel("TV_commercials_1950_2025.xlsx", engine='openpyxl')

# %%
df_tv_commercials
# Out:
#       Decade  Sequence                                    Title  \
# 0       1950         1                   Norwich Liquid Peptans
# 1       1950         2                       Betty Crocker Cake
# 2       1950         3  Easy Clean Kentile Vinyl Asbestos Floor
# 3       1950         4             Johnson's Floor Wax Polisher
# 4       1950         5    Best Foods Hellmann's Real Mayonnaise
# ..       ...       ...                                      ...
# 956  2020-25       116                                      NaN
# 957  2020-25       117                                      NaN
# 958  2020-25       118                                      NaN
# 959  2020-25       119                                      NaN
# 960  2020-25       120                                      NaN
#
#                             Category                           URL Start   End
# 0     Health, Beauty & Personal Care  https://youtu.be/G-zZFNf4PqQ   NaN   NaN
# 1        Food, Beverages & Nutrition  https://youtu.be/WMIMxj0PGGY  0:17  1:42
# 2    Household, Cleaning & Home Care  https://youtu.be/O-baiygWMTQ   NaN   NaN
# 3    Household, Cleaning & Home Care  https://youtu.be/GGcZsStUjTg   NaN   NaN
# 4        Food, Beverages & Nutrition  https://youtu.be/bh6rDLrRcsc   NaN   NaN
# ..                               ...                           ...   ...   ...
# 956                              NaN                           NaN   NaN   NaN
# 957                              NaN                           NaN   NaN   NaN
# 958                              NaN                           NaN   NaN   NaN
# 959                              NaN                           NaN   NaN   NaN
# 960                              NaN                           NaN   NaN   NaN
#
# [961 rows x 7 columns]

# %%
df_tv_commercials.dtypes
# Out:
# Decade      object
# Sequence     int64
# Title       object
# Category    object
# URL         object
# Start       object
# End         object
# dtype: object

# %%
df_tv_commercials.loc[1, 'Start']
# Out:
# '0:17'
